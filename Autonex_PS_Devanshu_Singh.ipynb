# %%
# !pip install simpy

# %%
# GLOBAL VARIABLE DEFINES THE NUMBER OF MACHINES AVAILABLE AND SYSTEM TIME
SHIFT_TIME = 480

ARRIVAL_MIN, ARRIVAL_MAX = 8, 12

CLEAN_MIN, CLEAN_MAX = 15, 20
PRIMER_MIN, PRIMER_MAX = 25, 35
PAINT_MIN, PAINT_MAX = 30, 40

CLEAN_MACHINES = 1
PRIMER_MACHINES = 2
PAINT_MACHINES = 1

# %%
# Imported necessary libraries
import simpy
import random
import statistics

# %%
car_count = 0                 # Total cars that entered the system
completed_cars = 0            # Cars that completed all stations

# System performance metrics
system_times = []             # Time spent by each car in the system
alerts_triggered = 0          # Number of bottleneck alerts raised

# Queue statistics
queue_max = {
    "Cleaning": 0,
    "Primer": 0,
    "Painting": 0
}

# Waiting time at each station
wait_times = {
    "Cleaning": [],
    "Primer": [],
    "Painting": []
}

# Busy time (used for utilization calculation)
busy_time = {
    "Cleaning": 0,
    "Primer": 0,
    "Painting": 0
}

# %%
# SimPy resources for each station
def create_stations(env):

    # Capacity = number of machines available.

    return (
        simpy.Resource(env, capacity=CLEAN_MACHINES),
        simpy.Resource(env, capacity=PRIMER_MACHINES),
        simpy.Resource(env, capacity=PAINT_MACHINES),
    )

# %%
def process_station(env, car_name, station_name, resource, min_t, max_t,
                    cleaning, primer, painting):
    """
    Simulates a single car passing through one station.
    Handles queueing, processing, metric collection, and real-time logging.
    """
    global alerts_triggered

    # Log the moment the car arrives at this station along with current queue status
    print(
        f"{car_name} arrived at {station_name} at time {env.now:.1f} | "
        f"{q_status(cleaning, primer, painting)}"
    )

    with resource.request() as req:

        # Capture queue length before acquiring the machine
        q_len = len(resource.queue)
        queue_max[station_name] = max(queue_max[station_name], q_len)

        # Trigger alert if queue length crosses threshold
        if q_len > 3:
            alerts_triggered += 1
            print(
                f"ALERT: Queue at {station_name} has "
                f"{q_len} cars waiting at time {env.now:.1f}"
            )

        # Measure waiting time until the car gets the machine
        wait_start = env.now
        yield req
        wait_times[station_name].append(env.now - wait_start)

        # Log start of processing with live queue status
        print(
            f"{car_name} started {station_name} at {env.now:.1f} | "
            f"{q_status(cleaning, primer, painting)}"
        )

        # Sample processing time using uniform distribution
        process_time = random.uniform(min_t, max_t)

        # Track machine busy time only within shift duration
        start = env.now
        end = start + process_time
        if start < SHIFT_TIME:
            busy_time[station_name] += min(end, SHIFT_TIME) - start

        # Simulate processing delay
        yield env.timeout(process_time)

        # Log completion of processing at this station
        print(
            f"{car_name} finished {station_name} at {env.now:.1f} | "
            f"{q_status(cleaning, primer, painting)}"
        )

# %%
def car(env, name, cleaning, primer, painting):

    global completed_cars

    # Record the time when the car enters the system
    arrival = env.now
    print(
        f"{name} arrived at time {env.now:.1f} | "
        f"{q_status(cleaning, primer, painting)}"
    )

    # Pass through Cleaning station
    yield from process_station(
        env, name, "Cleaning", cleaning, CLEAN_MIN, CLEAN_MAX,
        cleaning, primer, painting
    )

    # Pass through Primer station
    yield from process_station(
        env, name, "Primer", primer, PRIMER_MIN, PRIMER_MAX,
        cleaning, primer, painting
    )

    # Pass through Painting station
    yield from process_station(
        env, name, "Painting", painting, PAINT_MIN, PAINT_MAX,
        cleaning, primer, painting
    )

    # Update completion metrics once the car exits all stations
    completed_cars += 1
    system_times.append(env.now - arrival)

    # Log the car’s exit from the system with final queue snapshot
    print(
        f"{name} exited system at {env.now:.1f} | "
        f"{q_status(cleaning, primer, painting)}"
    )

# %%
def car_generator(env, cleaning, primer, painting):

    global car_count

    while True:
        inter = random.uniform(ARRIVAL_MIN, ARRIVAL_MAX)

        # No new cars are added after SHIFT_TIME, but existing cars finish processing
        if env.now + inter > SHIFT_TIME:
            break

        yield env.timeout(inter)

        car_count += 1
        env.process(car(env, f"Car-{car_count}", cleaning, primer, painting))

# %%
def q_status(cleaning, primer, painting):
    return (
        f"Q(Cleaning={len(cleaning.queue)}, "
        f"Primer={len(primer.queue)}, "
        f"Painting={len(painting.queue)})"
    )

# %%
env = simpy.Environment()

# Initialize station resources
cleaning, primer, painting = create_stations(env)

# Start the car arrival process
env.process(car_generator(env, cleaning, primer, painting))

# Run the simulation until all cars complete
env.run()
# Out:
# Car-1 arrived at time 8.6 | Q(Cleaning=0, Primer=0, Painting=0)
# Car-1 arrived at Cleaning at time 8.6 | Q(Cleaning=0, Primer=0, Painting=0)
# Car-1 started Cleaning at 8.6 | Q(Cleaning=0, Primer=0, Painting=0)
# Car-2 arrived at time 17.5 | Q(Cleaning=0, Primer=0, Painting=0)
# Car-2 arrived at Cleaning at time 17.5 | Q(Cleaning=0, Primer=0, Painting=0)
# Car-1 finished Cleaning at 25.3 | Q(Cleaning=1, Primer=0, Painting=0)
# Car-1 arrived at Primer at time 25.3 | Q(Cleaning=1, Primer=0, Painting=0)
# Car-1 started Primer at 25.3 | Q(Cleaning=0, Primer=0, Painting=0)
# Car-2 started Cleaning at 25.3 | Q(Cleaning=0, Primer=0, Painting=0)
# Car-3 arrived at time 27.5 | Q(Cleaning=0, Primer=0, Painting=0)
# Car-3 arrived at Cleaning at time 27.5 | Q(Cleaning=0, Primer=0, Painting=0)
# Car-4 arrived at time 36.7 | Q(Cleaning=1, Primer=0, Painting=0)
# Car-4 arrived at Cleaning at time 36.7 | Q(Cleaning=1, Primer=0, Painting=0)
# Car-2 finished Cleaning at 40.4 | Q(Cleaning=2, Primer=0, Painting=0)
# Car-2 arrived at Primer at time 40.4 | Q(Cleaning=2, Primer=0, Painting=0)
# Car-2 started Primer at 40.4 | Q(Cleaning=1, Primer=0, Painting=0)
# Car-3 started Cleaning at 40.4 | Q(Cleaning=1, Primer=0, Painting=0)
# Car-5 arrived at time 46.0 | Q(Cleaning=1, Primer=0, Painting=0)
# Car-5 arrived at Cleaning at time 46.0 | Q(Cleaning=1, Primer=0, Painting=0)
# Car-1 finished Primer at 52.0 | Q(Cleaning=2, Primer=0, Painting=0)
# Car-1 arrived at Painting at time 52.0 | Q(Cleaning=2, Primer=0, Painting=0)
# Car-1 started Painting at 52.0 | Q(Cleaning=2, Primer=0, Painting=0)
# Car-3 finished Cleaning at 56.6 | Q(Cleaning=2, Primer=0, Painting=0)
# Car-3 arrived at Primer at time 56.6 | Q(Cleaning=2, Primer=0, Painting=0)
# Car-3 started Primer at 56.6 | Q(Cleaning=1, Primer=0, Painting=0)
# Car-4 started Cleaning at 56.6 | Q(Cleaning=1, Primer=0, Painting=0)
# Car-6 arrived at time 57.7 | Q(Cleaning=1, Primer=0, Painting=0)
# Car-6 arrived at Cleaning at time 57.7 | Q(Cleaning=1, Primer=0, Painting=0)
# Car-7 arrived at time 66.7 | Q(Cleaning=2, Primer=0, Painting=0)
# Car-7 arrived at Cleaning at time 66.7 | Q(Cleaning=2, Primer=0, Painting=0)
# Car-2 finished Primer at 73.5 | Q(Cleaning=3, Primer=0, Painting=0)
# Car-2 arrived at Painting at time 73.5 | Q(Cleaning=3, Primer=0, Painting=0)
# Car-4 finished Cleaning at 76.4 | Q(Cleaning=3, Primer=0, Painting=1)
# Car-4 arrived at Primer at time 76.4 | Q(Cleaning=3, Primer=0, Painting=1)
# Car-4 started Primer at 76.4 | Q(Cleaning=2, Primer=0, Painting=1)
# Car-5 started Cleaning at 76.4 | Q(Cleaning=2, Primer=0, Painting=1)
# Car-8 arrived at time 78.5 | Q(Cleaning=2, Primer=0, Painting=1)
# Car-8 arrived at Cleaning at time 78.5 | Q(Cleaning=2, Primer=0, Painting=1)
# Car-3 finished Primer at 83.9 | Q(Cleaning=3, Primer=0, Painting=1)
# Car-3 arrived at Painting at time 83.9 | Q(Cleaning=3, Primer=0, Painting=1)
# Car-1 finished Painting at 84.2 | Q(Cleaning=3, Primer=0, Painting=2)
# Car-1 exited system at 84.2 | Q(Cleaning=3, Primer=0, Painting=2)
# Car-2 started Painting at 84.2 | Q(Cleaning=3, Primer=0, Painting=1)
# Car-9 arrived at time 87.3 | Q(Cleaning=3, Primer=0, Painting=1)
# Car-9 arrived at Cleaning at time 87.3 | Q(Cleaning=3, Primer=0, Painting=1)
# ALERT: Queue at Cleaning has 4 cars waiting at time 87.3
# Car-5 finished Cleaning at 95.3 | Q(Cleaning=4, Primer=0, Painting=1)
# Car-5 arrived at Primer at time 95.3 | Q(Cleaning=4, Primer=0, Painting=1)
# Car-5 started Primer at 95.3 | Q(Cleaning=3, Primer=0, Painting=1)
# Car-6 started Cleaning at 95.3 | Q(Cleaning=3, Primer=0, Painting=1)
# Car-10 arrived at time 98.0 | Q(Cleaning=3, Primer=0, Painting=1)
# Car-10 arrived at Cleaning at time 98.0 | Q(Cleaning=3, Primer=0, Painting=1)
# ALERT: Queue at Cleaning has 4 cars waiting at time 98.0
# Car-11 arrived at time 106.9 | Q(Cleaning=4, Primer=0, Painting=1)
# Car-11 arrived at Cleaning at time 106.9 | Q(Cleaning=4, Primer=0, Painting=1)
# ALERT: Queue at Cleaning has 5 cars waiting at time 106.9
# Car-4 finished Primer at 110.5 | Q(Cleaning=5, Primer=0, Painting=1)
# Car-4 arrived at Painting at time 110.5 | Q(Cleaning=5, Primer=0, Painting=1)
# Car-6 finished Cleaning at 114.5 | Q(Cleaning=5, Primer=0, Painting=2)
# Car-6 arrived at Primer at time 114.5 | Q(Cleaning=5, Primer=0, Painting=2)
# Car-6 started Primer at 114.5 | Q(Cleaning=4, Primer=0, Painting=2)
# Car-7 started Cleaning at 114.5 | Q(Cleaning=4, Primer=0, Painting=2)
# Car-12 arrived at time 116.4 | Q(Cleaning=4, Primer=0, Painting=2)
# Car-12 arrived at Cleaning at time 116.4 | Q(Cleaning=4, Primer=0, Painting=2)
# ALERT: Queue at Cleaning has 5 cars waiting at time 116.4
# Car-2 finished Painting at 120.6 | Q(Cleaning=5, Primer=0, Painting=2)
# Car-2 exited system at 120.6 | Q(Cleaning=5, Primer=0, Painting=2)
# Car-3 started Painting at 120.6 | Q(Cleaning=5, Primer=0, Painting=1)
# Car-5 finished Primer at 121.7 | Q(Cleaning=5, Primer=0, Painting=1)
# Car-5 arrived at Painting at time 121.7 | Q(Cleaning=5, Primer=0, Painting=1)
# Car-13 arrived at time 127.4 | Q(Cleaning=5, Primer=0, Painting=2)
# Car-13 arrived at Cleaning at time 127.4 | Q(Cleaning=5, Primer=0, Painting=2)
# ALERT: Queue at Cleaning has 6 cars waiting at time 127.4
# Car-7 finished Cleaning at 129.5 | Q(Cleaning=6, Primer=0, Painting=2)
# Car-7 arrived at Primer at time 129.5 | Q(Cleaning=6, Primer=0, Painting=2)
# Car-7 started Primer at 129.5 | Q(Cleaning=5, Primer=0, Painting=2)
# Car-8 started Cleaning at 129.5 | Q(Cleaning=5, Primer=0, Painting=2)
# Car-14 arrived at time 138.5 | Q(Cleaning=5, Primer=0, Painting=2)
# Car-14 arrived at Cleaning at time 138.5 | Q(Cleaning=5, Primer=0, Painting=2)
# ALERT: Queue at Cleaning has 6 cars waiting at time 138.5
# Car-6 finished Primer at 143.7 | Q(Cleaning=6, Primer=0, Painting=2)
# Car-6 arrived at Painting at time 143.7 | Q(Cleaning=6, Primer=0, Painting=2)
# Car-8 finished Cleaning at 147.4 | Q(Cleaning=6, Primer=0, Painting=3)
# Car-8 arrived at Primer at time 147.4 | Q(Cleaning=6, Primer=0, Painting=3)
# Car-8 started Primer at 147.4 | Q(Cleaning=5, Primer=0, Painting=3)
# Car-9 started Cleaning at 147.4 | Q(Cleaning=5, Primer=0, Painting=3)
# Car-15 arrived at time 148.5 | Q(Cleaning=5, Primer=0, Painting=3)
# Car-15 arrived at Cleaning at time 148.5 | Q(Cleaning=5, Primer=0, Painting=3)
# ALERT: Queue at Cleaning has 6 cars waiting at time 148.5
# Car-3 finished Painting at 158.4 | Q(Cleaning=6, Primer=0, Painting=3)
# Car-3 exited system at 158.4 | Q(Cleaning=6, Primer=0, Painting=3)
# Car-4 started Painting at 158.4 | Q(Cleaning=6, Primer=0, Painting=2)
# Car-16 arrived at time 159.0 | Q(Cleaning=6, Primer=0, Painting=2)
# Car-16 arrived at Cleaning at time 159.0 | Q(Cleaning=6, Primer=0, Painting=2)
# ALERT: Queue at Cleaning has 7 cars waiting at time 159.0
# Car-7 finished Primer at 160.4 | Q(Cleaning=7, Primer=0, Painting=2)
# Car-7 arrived at Painting at time 160.4 | Q(Cleaning=7, Primer=0, Painting=2)
# Car-9 finished Cleaning at 165.8 | Q(Cleaning=7, Primer=0, Painting=3)
# Car-9 arrived at Primer at time 165.8 | Q(Cleaning=7, Primer=0, Painting=3)
# Car-9 started Primer at 165.8 | Q(Cleaning=6, Primer=0, Painting=3)
# Car-10 started Cleaning at 165.8 | Q(Cleaning=6, Primer=0, Painting=3)
# Car-17 arrived at time 169.3 | Q(Cleaning=6, Primer=0, Painting=3)
# Car-17 arrived at Cleaning at time 169.3 | Q(Cleaning=6, Primer=0, Painting=3)
# ALERT: Queue at Cleaning has 7 cars waiting at time 169.3
# Car-18 arrived at time 180.4 | Q(Cleaning=7, Primer=0, Painting=3)
# Car-18 arrived at Cleaning at time 180.4 | Q(Cleaning=7, Primer=0, Painting=3)
# ALERT: Queue at Cleaning has 8 cars waiting at time 180.4
# Car-8 finished Primer at 181.2 | Q(Cleaning=8, Primer=0, Painting=3)
# Car-8 arrived at Painting at time 181.2 | Q(Cleaning=8, Primer=0, Painting=3)
# ALERT: Queue at Painting has 4 cars waiting at time 181.2
# Car-10 finished Cleaning at 181.7 | Q(Cleaning=8, Primer=0, Painting=4)
# Car-10 arrived at Primer at time 181.7 | Q(Cleaning=8, Primer=0, Painting=4)
# Car-10 started Primer at 181.7 | Q(Cleaning=7, Primer=0, Painting=4)
# Car-11 started Cleaning at 181.7 | Q(Cleaning=7, Primer=0, Painting=4)
# Car-19 arrived at time 192.2 | Q(Cleaning=7, Primer=0, Painting=4)
# Car-19 arrived at Cleaning at time 192.2 | Q(Cleaning=7, Primer=0, Painting=4)
# ALERT: Queue at Cleaning has 8 cars waiting at time 192.2
# Car-4 finished Painting at 196.9 | Q(Cleaning=8, Primer=0, Painting=4)
# Car-4 exited system at 196.9 | Q(Cleaning=8, Primer=0, Painting=4)
# Car-5 started Painting at 196.9 | Q(Cleaning=8, Primer=0, Painting=3)
# Car-9 finished Primer at 200.5 | Q(Cleaning=8, Primer=0, Painting=3)
# Car-9 arrived at Painting at time 200.5 | Q(Cleaning=8, Primer=0, Painting=3)
# ALERT: Queue at Painting has 4 cars waiting at time 200.5
# Car-11 finished Cleaning at 200.5 | Q(Cleaning=8, Primer=0, Painting=4)
# Car-11 arrived at Primer at time 200.5 | Q(Cleaning=8, Primer=0, Painting=4)
# Car-11 started Primer at 200.5 | Q(Cleaning=7, Primer=0, Painting=4)
# Car-12 started Cleaning at 200.5 | Q(Cleaning=7, Primer=0, Painting=4)
# Car-20 arrived at time 203.5 | Q(Cleaning=7, Primer=0, Painting=4)
# Car-20 arrived at Cleaning at time 203.5 | Q(Cleaning=7, Primer=0, Painting=4)
# ALERT: Queue at Cleaning has 8 cars waiting at time 203.5
# Car-10 finished Primer at 214.2 | Q(Cleaning=8, Primer=0, Painting=4)
# Car-10 arrived at Painting at time 214.2 | Q(Cleaning=8, Primer=0, Painting=4)
# ALERT: Queue at Painting has 5 cars waiting at time 214.2
# Car-21 arrived at time 215.1 | Q(Cleaning=8, Primer=0, Painting=5)
# Car-21 arrived at Cleaning at time 215.1 | Q(Cleaning=8, Primer=0, Painting=5)
# ALERT: Queue at Cleaning has 9 cars waiting at time 215.1
# Car-12 finished Cleaning at 215.9 | Q(Cleaning=9, Primer=0, Painting=5)
# Car-12 arrived at Primer at time 215.9 | Q(Cleaning=9, Primer=0, Painting=5)
# Car-12 started Primer at 215.9 | Q(Cleaning=8, Primer=0, Painting=5)
# Car-13 started Cleaning at 215.9 | Q(Cleaning=8, Primer=0, Painting=5)
# Car-22 arrived at time 226.1 | Q(Cleaning=8, Primer=0, Painting=5)
# Car-22 arrived at Cleaning at time 226.1 | Q(Cleaning=8, Primer=0, Painting=5)
# ALERT: Queue at Cleaning has 9 cars waiting at time 226.1
# Car-5 finished Painting at 230.5 | Q(Cleaning=9, Primer=0, Painting=5)
# Car-5 exited system at 230.5 | Q(Cleaning=9, Primer=0, Painting=5)
# Car-6 started Painting at 230.5 | Q(Cleaning=9, Primer=0, Painting=4)
# Car-13 finished Cleaning at 233.0 | Q(Cleaning=9, Primer=0, Painting=4)
# Car-13 arrived at Primer at time 233.0 | Q(Cleaning=9, Primer=0, Painting=4)
# Car-14 started Cleaning at 233.0 | Q(Cleaning=8, Primer=1, Painting=4)
# Car-11 finished Primer at 234.2 | Q(Cleaning=8, Primer=1, Painting=4)
# Car-11 arrived at Painting at time 234.2 | Q(Cleaning=8, Primer=1, Painting=4)
# ALERT: Queue at Painting has 5 cars waiting at time 234.2
# Car-13 started Primer at 234.2 | Q(Cleaning=8, Primer=0, Painting=5)
# Car-23 arrived at time 235.8 | Q(Cleaning=8, Primer=0, Painting=5)
# Car-23 arrived at Cleaning at time 235.8 | Q(Cleaning=8, Primer=0, Painting=5)
# ALERT: Queue at Cleaning has 9 cars waiting at time 235.8
# Car-24 arrived at time 245.5 | Q(Cleaning=9, Primer=0, Painting=5)
# Car-24 arrived at Cleaning at time 245.5 | Q(Cleaning=9, Primer=0, Painting=5)
# ALERT: Queue at Cleaning has 10 cars waiting at time 245.5
# Car-12 finished Primer at 246.9 | Q(Cleaning=10, Primer=0, Painting=5)
# Car-12 arrived at Painting at time 246.9 | Q(Cleaning=10, Primer=0, Painting=5)
# ALERT: Queue at Painting has 6 cars waiting at time 246.9
# Car-14 finished Cleaning at 248.4 | Q(Cleaning=10, Primer=0, Painting=6)
# Car-14 arrived at Primer at time 248.4 | Q(Cleaning=10, Primer=0, Painting=6)
# Car-14 started Primer at 248.4 | Q(Cleaning=9, Primer=0, Painting=6)
# Car-15 started Cleaning at 248.4 | Q(Cleaning=9, Primer=0, Painting=6)
# Car-25 arrived at time 254.1 | Q(Cleaning=9, Primer=0, Painting=6)
# Car-25 arrived at Cleaning at time 254.1 | Q(Cleaning=9, Primer=0, Painting=6)
# ALERT: Queue at Cleaning has 10 cars waiting at time 254.1
# Car-26 arrived at time 264.8 | Q(Cleaning=10, Primer=0, Painting=6)
# Car-26 arrived at Cleaning at time 264.8 | Q(Cleaning=10, Primer=0, Painting=6)
# ALERT: Queue at Cleaning has 11 cars waiting at time 264.8
# Car-15 finished Cleaning at 265.2 | Q(Cleaning=11, Primer=0, Painting=6)
# Car-15 arrived at Primer at time 265.2 | Q(Cleaning=11, Primer=0, Painting=6)
# Car-16 started Cleaning at 265.2 | Q(Cleaning=10, Primer=1, Painting=6)
# Car-6 finished Painting at 266.2 | Q(Cleaning=10, Primer=1, Painting=6)
# Car-6 exited system at 266.2 | Q(Cleaning=10, Primer=1, Painting=6)
# Car-7 started Painting at 266.2 | Q(Cleaning=10, Primer=1, Painting=5)
# Car-13 finished Primer at 266.4 | Q(Cleaning=10, Primer=1, Painting=5)
# Car-13 arrived at Painting at time 266.4 | Q(Cleaning=10, Primer=1, Painting=5)
# ALERT: Queue at Painting has 6 cars waiting at time 266.4
# Car-15 started Primer at 266.4 | Q(Cleaning=10, Primer=0, Painting=6)
# Car-27 arrived at time 276.5 | Q(Cleaning=10, Primer=0, Painting=6)
# Car-27 arrived at Cleaning at time 276.5 | Q(Cleaning=10, Primer=0, Painting=6)
# ALERT: Queue at Cleaning has 11 cars waiting at time 276.5
# Car-14 finished Primer at 278.1 | Q(Cleaning=11, Primer=0, Painting=6)
# Car-14 arrived at Painting at time 278.1 | Q(Cleaning=11, Primer=0, Painting=6)
# ALERT: Queue at Painting has 7 cars waiting at time 278.1
# Car-16 finished Cleaning at 281.0 | Q(Cleaning=11, Primer=0, Painting=7)
# Car-16 arrived at Primer at time 281.0 | Q(Cleaning=11, Primer=0, Painting=7)
# Car-16 started Primer at 281.0 | Q(Cleaning=10, Primer=0, Painting=7)
# Car-17 started Cleaning at 281.0 | Q(Cleaning=10, Primer=0, Painting=7)
# Car-28 arrived at time 288.4 | Q(Cleaning=10, Primer=0, Painting=7)
# Car-28 arrived at Cleaning at time 288.4 | Q(Cleaning=10, Primer=0, Painting=7)
# ALERT: Queue at Cleaning has 11 cars waiting at time 288.4
# Car-17 finished Cleaning at 297.2 | Q(Cleaning=11, Primer=0, Painting=7)
# Car-17 arrived at Primer at time 297.2 | Q(Cleaning=11, Primer=0, Painting=7)
# Car-18 started Cleaning at 297.2 | Q(Cleaning=10, Primer=1, Painting=7)
# Car-29 arrived at time 298.9 | Q(Cleaning=10, Primer=1, Painting=7)
# Car-29 arrived at Cleaning at time 298.9 | Q(Cleaning=10, Primer=1, Painting=7)
# ALERT: Queue at Cleaning has 11 cars waiting at time 298.9
# Car-15 finished Primer at 299.7 | Q(Cleaning=11, Primer=1, Painting=7)
# Car-15 arrived at Painting at time 299.7 | Q(Cleaning=11, Primer=1, Painting=7)
# ALERT: Queue at Painting has 8 cars waiting at time 299.7
# Car-17 started Primer at 299.7 | Q(Cleaning=11, Primer=0, Painting=8)
# Car-7 finished Painting at 305.8 | Q(Cleaning=11, Primer=0, Painting=8)
# Car-7 exited system at 305.8 | Q(Cleaning=11, Primer=0, Painting=8)
# Car-8 started Painting at 305.8 | Q(Cleaning=11, Primer=0, Painting=7)
# Car-16 finished Primer at 308.2 | Q(Cleaning=11, Primer=0, Painting=7)
# Car-16 arrived at Painting at time 308.2 | Q(Cleaning=11, Primer=0, Painting=7)
# ALERT: Queue at Painting has 8 cars waiting at time 308.2
# Car-30 arrived at time 309.1 | Q(Cleaning=11, Primer=0, Painting=8)
# Car-30 arrived at Cleaning at time 309.1 | Q(Cleaning=11, Primer=0, Painting=8)
# ALERT: Queue at Cleaning has 12 cars waiting at time 309.1
# Car-18 finished Cleaning at 314.0 | Q(Cleaning=12, Primer=0, Painting=8)
# Car-18 arrived at Primer at time 314.0 | Q(Cleaning=12, Primer=0, Painting=8)
# Car-18 started Primer at 314.0 | Q(Cleaning=11, Primer=0, Painting=8)
# Car-19 started Cleaning at 314.0 | Q(Cleaning=11, Primer=0, Painting=8)
# Car-31 arrived at time 317.6 | Q(Cleaning=11, Primer=0, Painting=8)
# Car-31 arrived at Cleaning at time 317.6 | Q(Cleaning=11, Primer=0, Painting=8)
# ALERT: Queue at Cleaning has 12 cars waiting at time 317.6
# Car-32 arrived at time 327.1 | Q(Cleaning=12, Primer=0, Painting=8)
# Car-32 arrived at Cleaning at time 327.1 | Q(Cleaning=12, Primer=0, Painting=8)
# ALERT: Queue at Cleaning has 13 cars waiting at time 327.1
# Car-19 finished Cleaning at 329.3 | Q(Cleaning=13, Primer=0, Painting=8)
# Car-19 arrived at Primer at time 329.3 | Q(Cleaning=13, Primer=0, Painting=8)
# Car-20 started Cleaning at 329.3 | Q(Cleaning=12, Primer=1, Painting=8)
# Car-17 finished Primer at 333.1 | Q(Cleaning=12, Primer=1, Painting=8)
# Car-17 arrived at Painting at time 333.1 | Q(Cleaning=12, Primer=1, Painting=8)
# ALERT: Queue at Painting has 9 cars waiting at time 333.1
# Car-19 started Primer at 333.1 | Q(Cleaning=12, Primer=0, Painting=9)
# Car-33 arrived at time 335.3 | Q(Cleaning=12, Primer=0, Painting=9)
# Car-33 arrived at Cleaning at time 335.3 | Q(Cleaning=12, Primer=0, Painting=9)
# ALERT: Queue at Cleaning has 13 cars waiting at time 335.3
# Car-8 finished Painting at 338.1 | Q(Cleaning=13, Primer=0, Painting=9)
# Car-8 exited system at 338.1 | Q(Cleaning=13, Primer=0, Painting=9)
# Car-9 started Painting at 338.1 | Q(Cleaning=13, Primer=0, Painting=8)
# Car-18 finished Primer at 340.7 | Q(Cleaning=13, Primer=0, Painting=8)
# Car-18 arrived at Painting at time 340.7 | Q(Cleaning=13, Primer=0, Painting=8)
# ALERT: Queue at Painting has 9 cars waiting at time 340.7
# Car-34 arrived at time 345.4 | Q(Cleaning=13, Primer=0, Painting=9)
# Car-34 arrived at Cleaning at time 345.4 | Q(Cleaning=13, Primer=0, Painting=9)
# ALERT: Queue at Cleaning has 14 cars waiting at time 345.4
# Car-20 finished Cleaning at 347.7 | Q(Cleaning=14, Primer=0, Painting=9)
# Car-20 arrived at Primer at time 347.7 | Q(Cleaning=14, Primer=0, Painting=9)
# Car-20 started Primer at 347.7 | Q(Cleaning=13, Primer=0, Painting=9)
# Car-21 started Cleaning at 347.7 | Q(Cleaning=13, Primer=0, Painting=9)
# Car-35 arrived at time 357.0 | Q(Cleaning=13, Primer=0, Painting=9)
# Car-35 arrived at Cleaning at time 357.0 | Q(Cleaning=13, Primer=0, Painting=9)
# ALERT: Queue at Cleaning has 14 cars waiting at time 357.0
# Car-19 finished Primer at 363.2 | Q(Cleaning=14, Primer=0, Painting=9)
# Car-19 arrived at Painting at time 363.2 | Q(Cleaning=14, Primer=0, Painting=9)
# ALERT: Queue at Painting has 10 cars waiting at time 363.2
# Car-21 finished Cleaning at 364.8 | Q(Cleaning=14, Primer=0, Painting=10)
# Car-21 arrived at Primer at time 364.8 | Q(Cleaning=14, Primer=0, Painting=10)
# Car-21 started Primer at 364.8 | Q(Cleaning=13, Primer=0, Painting=10)
# Car-22 started Cleaning at 364.8 | Q(Cleaning=13, Primer=0, Painting=10)
# Car-36 arrived at time 365.9 | Q(Cleaning=13, Primer=0, Painting=10)
# Car-36 arrived at Cleaning at time 365.9 | Q(Cleaning=13, Primer=0, Painting=10)
# ALERT: Queue at Cleaning has 14 cars waiting at time 365.9
# Car-9 finished Painting at 371.5 | Q(Cleaning=14, Primer=0, Painting=10)
# Car-9 exited system at 371.5 | Q(Cleaning=14, Primer=0, Painting=10)
# Car-10 started Painting at 371.5 | Q(Cleaning=14, Primer=0, Painting=9)
# Car-37 arrived at time 376.6 | Q(Cleaning=14, Primer=0, Painting=9)
# Car-37 arrived at Cleaning at time 376.6 | Q(Cleaning=14, Primer=0, Painting=9)
# ALERT: Queue at Cleaning has 15 cars waiting at time 376.6
# Car-22 finished Cleaning at 380.2 | Q(Cleaning=15, Primer=0, Painting=9)
# Car-22 arrived at Primer at time 380.2 | Q(Cleaning=15, Primer=0, Painting=9)
# Car-23 started Cleaning at 380.2 | Q(Cleaning=14, Primer=1, Painting=9)
# Car-20 finished Primer at 380.9 | Q(Cleaning=14, Primer=1, Painting=9)
# Car-20 arrived at Painting at time 380.9 | Q(Cleaning=14, Primer=1, Painting=9)
# ALERT: Queue at Painting has 10 cars waiting at time 380.9
# Car-22 started Primer at 380.9 | Q(Cleaning=14, Primer=0, Painting=10)
# Car-38 arrived at time 385.7 | Q(Cleaning=14, Primer=0, Painting=10)
# Car-38 arrived at Cleaning at time 385.7 | Q(Cleaning=14, Primer=0, Painting=10)
# ALERT: Queue at Cleaning has 15 cars waiting at time 385.7
# Car-21 finished Primer at 390.5 | Q(Cleaning=15, Primer=0, Painting=10)
# Car-21 arrived at Painting at time 390.5 | Q(Cleaning=15, Primer=0, Painting=10)
# ALERT: Queue at Painting has 11 cars waiting at time 390.5
# Car-39 arrived at time 396.8 | Q(Cleaning=15, Primer=0, Painting=11)
# Car-39 arrived at Cleaning at time 396.8 | Q(Cleaning=15, Primer=0, Painting=11)
# ALERT: Queue at Cleaning has 16 cars waiting at time 396.8
# Car-23 finished Cleaning at 398.9 | Q(Cleaning=16, Primer=0, Painting=11)
# Car-23 arrived at Primer at time 398.9 | Q(Cleaning=16, Primer=0, Painting=11)
# Car-23 started Primer at 398.9 | Q(Cleaning=15, Primer=0, Painting=11)
# Car-24 started Cleaning at 398.9 | Q(Cleaning=15, Primer=0, Painting=11)
# Car-10 finished Painting at 402.3 | Q(Cleaning=15, Primer=0, Painting=11)
# Car-10 exited system at 402.3 | Q(Cleaning=15, Primer=0, Painting=11)
# Car-11 started Painting at 402.3 | Q(Cleaning=15, Primer=0, Painting=10)
# Car-40 arrived at time 405.1 | Q(Cleaning=15, Primer=0, Painting=10)
# Car-40 arrived at Cleaning at time 405.1 | Q(Cleaning=15, Primer=0, Painting=10)
# ALERT: Queue at Cleaning has 16 cars waiting at time 405.1
# Car-22 finished Primer at 412.9 | Q(Cleaning=16, Primer=0, Painting=10)
# Car-22 arrived at Painting at time 412.9 | Q(Cleaning=16, Primer=0, Painting=10)
# ALERT: Queue at Painting has 11 cars waiting at time 412.9
# Car-41 arrived at time 416.1 | Q(Cleaning=16, Primer=0, Painting=11)
# Car-41 arrived at Cleaning at time 416.1 | Q(Cleaning=16, Primer=0, Painting=11)
# ALERT: Queue at Cleaning has 17 cars waiting at time 416.1
# Car-24 finished Cleaning at 416.8 | Q(Cleaning=17, Primer=0, Painting=11)
# Car-24 arrived at Primer at time 416.8 | Q(Cleaning=17, Primer=0, Painting=11)
# Car-24 started Primer at 416.8 | Q(Cleaning=16, Primer=0, Painting=11)
# Car-25 started Cleaning at 416.8 | Q(Cleaning=16, Primer=0, Painting=11)
# Car-42 arrived at time 428.0 | Q(Cleaning=16, Primer=0, Painting=11)
# Car-42 arrived at Cleaning at time 428.0 | Q(Cleaning=16, Primer=0, Painting=11)
# ALERT: Queue at Cleaning has 17 cars waiting at time 428.0
# Car-23 finished Primer at 433.7 | Q(Cleaning=17, Primer=0, Painting=11)
# Car-23 arrived at Painting at time 433.7 | Q(Cleaning=17, Primer=0, Painting=11)
# ALERT: Queue at Painting has 12 cars waiting at time 433.7
# Car-11 finished Painting at 435.9 | Q(Cleaning=17, Primer=0, Painting=12)
# Car-11 exited system at 435.9 | Q(Cleaning=17, Primer=0, Painting=12)
# Car-12 started Painting at 435.9 | Q(Cleaning=17, Primer=0, Painting=11)
# Car-25 finished Cleaning at 436.0 | Q(Cleaning=17, Primer=0, Painting=11)
# Car-25 arrived at Primer at time 436.0 | Q(Cleaning=17, Primer=0, Painting=11)
# Car-25 started Primer at 436.0 | Q(Cleaning=16, Primer=0, Painting=11)
# Car-26 started Cleaning at 436.0 | Q(Cleaning=16, Primer=0, Painting=11)
# Car-43 arrived at time 436.6 | Q(Cleaning=16, Primer=0, Painting=11)
# Car-43 arrived at Cleaning at time 436.6 | Q(Cleaning=16, Primer=0, Painting=11)
# ALERT: Queue at Cleaning has 17 cars waiting at time 436.6
# Car-44 arrived at time 446.1 | Q(Cleaning=17, Primer=0, Painting=11)
# Car-44 arrived at Cleaning at time 446.1 | Q(Cleaning=17, Primer=0, Painting=11)
# ALERT: Queue at Cleaning has 18 cars waiting at time 446.1
# Car-24 finished Primer at 450.3 | Q(Cleaning=18, Primer=0, Painting=11)
# Car-24 arrived at Painting at time 450.3 | Q(Cleaning=18, Primer=0, Painting=11)
# ALERT: Queue at Painting has 12 cars waiting at time 450.3
# Car-26 finished Cleaning at 454.3 | Q(Cleaning=18, Primer=0, Painting=12)
# Car-26 arrived at Primer at time 454.3 | Q(Cleaning=18, Primer=0, Painting=12)
# Car-26 started Primer at 454.3 | Q(Cleaning=17, Primer=0, Painting=12)
# Car-27 started Cleaning at 454.3 | Q(Cleaning=17, Primer=0, Painting=12)
# Car-45 arrived at time 456.8 | Q(Cleaning=17, Primer=0, Painting=12)
# Car-45 arrived at Cleaning at time 456.8 | Q(Cleaning=17, Primer=0, Painting=12)
# ALERT: Queue at Cleaning has 18 cars waiting at time 456.8
# Car-25 finished Primer at 465.9 | Q(Cleaning=18, Primer=0, Painting=12)
# Car-25 arrived at Painting at time 465.9 | Q(Cleaning=18, Primer=0, Painting=12)
# ALERT: Queue at Painting has 13 cars waiting at time 465.9
# Car-46 arrived at time 468.1 | Q(Cleaning=18, Primer=0, Painting=13)
# Car-46 arrived at Cleaning at time 468.1 | Q(Cleaning=18, Primer=0, Painting=13)
# ALERT: Queue at Cleaning has 19 cars waiting at time 468.1
# Car-12 finished Painting at 471.6 | Q(Cleaning=19, Primer=0, Painting=13)
# Car-12 exited system at 471.6 | Q(Cleaning=19, Primer=0, Painting=13)
# Car-13 started Painting at 471.6 | Q(Cleaning=19, Primer=0, Painting=12)
# Car-27 finished Cleaning at 472.6 | Q(Cleaning=19, Primer=0, Painting=12)
# Car-27 arrived at Primer at time 472.6 | Q(Cleaning=19, Primer=0, Painting=12)
# Car-27 started Primer at 472.6 | Q(Cleaning=18, Primer=0, Painting=12)
# Car-28 started Cleaning at 472.6 | Q(Cleaning=18, Primer=0, Painting=12)
# Car-47 arrived at time 478.2 | Q(Cleaning=18, Primer=0, Painting=12)
# Car-47 arrived at Cleaning at time 478.2 | Q(Cleaning=18, Primer=0, Painting=12)
# ALERT: Queue at Cleaning has 19 cars waiting at time 478.2
# Car-26 finished Primer at 480.4 | Q(Cleaning=19, Primer=0, Painting=12)
# Car-26 arrived at Painting at time 480.4 | Q(Cleaning=19, Primer=0, Painting=12)
# ALERT: Queue at Painting has 13 cars waiting at time 480.4
# Car-28 finished Cleaning at 492.2 | Q(Cleaning=19, Primer=0, Painting=13)
# Car-28 arrived at Primer at time 492.2 | Q(Cleaning=19, Primer=0, Painting=13)
# Car-28 started Primer at 492.2 | Q(Cleaning=18, Primer=0, Painting=13)
# Car-29 started Cleaning at 492.2 | Q(Cleaning=18, Primer=0, Painting=13)
# Car-27 finished Primer at 503.7 | Q(Cleaning=18, Primer=0, Painting=13)
# Car-27 arrived at Painting at time 503.7 | Q(Cleaning=18, Primer=0, Painting=13)
# ALERT: Queue at Painting has 14 cars waiting at time 503.7
# Car-13 finished Painting at 507.8 | Q(Cleaning=18, Primer=0, Painting=14)
# Car-13 exited system at 507.8 | Q(Cleaning=18, Primer=0, Painting=14)
# Car-14 started Painting at 507.8 | Q(Cleaning=18, Primer=0, Painting=13)
# Car-29 finished Cleaning at 508.8 | Q(Cleaning=18, Primer=0, Painting=13)
# Car-29 arrived at Primer at time 508.8 | Q(Cleaning=18, Primer=0, Painting=13)
# Car-29 started Primer at 508.8 | Q(Cleaning=17, Primer=0, Painting=13)
# Car-30 started Cleaning at 508.8 | Q(Cleaning=17, Primer=0, Painting=13)
# Car-30 finished Cleaning at 525.2 | Q(Cleaning=17, Primer=0, Painting=13)
# Car-30 arrived at Primer at time 525.2 | Q(Cleaning=17, Primer=0, Painting=13)
# Car-31 started Cleaning at 525.2 | Q(Cleaning=16, Primer=1, Painting=13)
# Car-28 finished Primer at 526.8 | Q(Cleaning=16, Primer=1, Painting=13)
# Car-28 arrived at Painting at time 526.8 | Q(Cleaning=16, Primer=1, Painting=13)
# ALERT: Queue at Painting has 14 cars waiting at time 526.8
# Car-30 started Primer at 526.8 | Q(Cleaning=16, Primer=0, Painting=14)
# Car-29 finished Primer at 536.2 | Q(Cleaning=16, Primer=0, Painting=14)
# Car-29 arrived at Painting at time 536.2 | Q(Cleaning=16, Primer=0, Painting=14)
# ALERT: Queue at Painting has 15 cars waiting at time 536.2
# Car-14 finished Painting at 540.8 | Q(Cleaning=16, Primer=0, Painting=15)
# Car-14 exited system at 540.8 | Q(Cleaning=16, Primer=0, Painting=15)
# Car-15 started Painting at 540.8 | Q(Cleaning=16, Primer=0, Painting=14)
# Car-31 finished Cleaning at 544.4 | Q(Cleaning=16, Primer=0, Painting=14)
# Car-31 arrived at Primer at time 544.4 | Q(Cleaning=16, Primer=0, Painting=14)
# Car-31 started Primer at 544.4 | Q(Cleaning=15, Primer=0, Painting=14)
# Car-32 started Cleaning at 544.4 | Q(Cleaning=15, Primer=0, Painting=14)
# Car-30 finished Primer at 557.0 | Q(Cleaning=15, Primer=0, Painting=14)
# Car-30 arrived at Painting at time 557.0 | Q(Cleaning=15, Primer=0, Painting=14)
# ALERT: Queue at Painting has 15 cars waiting at time 557.0
# Car-32 finished Cleaning at 562.9 | Q(Cleaning=15, Primer=0, Painting=15)
# Car-32 arrived at Primer at time 562.9 | Q(Cleaning=15, Primer=0, Painting=15)
# Car-32 started Primer at 562.9 | Q(Cleaning=14, Primer=0, Painting=15)
# Car-33 started Cleaning at 562.9 | Q(Cleaning=14, Primer=0, Painting=15)
# Car-15 finished Painting at 573.2 | Q(Cleaning=14, Primer=0, Painting=15)
# Car-15 exited system at 573.2 | Q(Cleaning=14, Primer=0, Painting=15)
# Car-16 started Painting at 573.2 | Q(Cleaning=14, Primer=0, Painting=14)
# Car-31 finished Primer at 577.4 | Q(Cleaning=14, Primer=0, Painting=14)
# Car-31 arrived at Painting at time 577.4 | Q(Cleaning=14, Primer=0, Painting=14)
# ALERT: Queue at Painting has 15 cars waiting at time 577.4
# Car-33 finished Cleaning at 582.8 | Q(Cleaning=14, Primer=0, Painting=15)
# Car-33 arrived at Primer at time 582.8 | Q(Cleaning=14, Primer=0, Painting=15)
# Car-33 started Primer at 582.8 | Q(Cleaning=13, Primer=0, Painting=15)
# Car-34 started Cleaning at 582.8 | Q(Cleaning=13, Primer=0, Painting=15)
# Car-32 finished Primer at 589.3 | Q(Cleaning=13, Primer=0, Painting=15)
# Car-32 arrived at Painting at time 589.3 | Q(Cleaning=13, Primer=0, Painting=15)
# ALERT: Queue at Painting has 16 cars waiting at time 589.3
# Car-34 finished Cleaning at 602.2 | Q(Cleaning=13, Primer=0, Painting=16)
# Car-34 arrived at Primer at time 602.2 | Q(Cleaning=13, Primer=0, Painting=16)
# Car-34 started Primer at 602.2 | Q(Cleaning=12, Primer=0, Painting=16)
# Car-35 started Cleaning at 602.2 | Q(Cleaning=12, Primer=0, Painting=16)
# Car-16 finished Painting at 605.8 | Q(Cleaning=12, Primer=0, Painting=16)
# Car-16 exited system at 605.8 | Q(Cleaning=12, Primer=0, Painting=16)
# Car-17 started Painting at 605.8 | Q(Cleaning=12, Primer=0, Painting=15)
# Car-33 finished Primer at 615.5 | Q(Cleaning=12, Primer=0, Painting=15)
# Car-33 arrived at Painting at time 615.5 | Q(Cleaning=12, Primer=0, Painting=15)
# ALERT: Queue at Painting has 16 cars waiting at time 615.5
# Car-35 finished Cleaning at 620.6 | Q(Cleaning=12, Primer=0, Painting=16)
# Car-35 arrived at Primer at time 620.6 | Q(Cleaning=12, Primer=0, Painting=16)
# Car-35 started Primer at 620.6 | Q(Cleaning=11, Primer=0, Painting=16)
# Car-36 started Cleaning at 620.6 | Q(Cleaning=11, Primer=0, Painting=16)
# Car-34 finished Primer at 634.2 | Q(Cleaning=11, Primer=0, Painting=16)
# Car-34 arrived at Painting at time 634.2 | Q(Cleaning=11, Primer=0, Painting=16)
# ALERT: Queue at Painting has 17 cars waiting at time 634.2
# Car-17 finished Painting at 637.5 | Q(Cleaning=11, Primer=0, Painting=17)
# Car-17 exited system at 637.5 | Q(Cleaning=11, Primer=0, Painting=17)
# Car-18 started Painting at 637.5 | Q(Cleaning=11, Primer=0, Painting=16)
# Car-36 finished Cleaning at 640.4 | Q(Cleaning=11, Primer=0, Painting=16)
# Car-36 arrived at Primer at time 640.4 | Q(Cleaning=11, Primer=0, Painting=16)
# Car-36 started Primer at 640.4 | Q(Cleaning=10, Primer=0, Painting=16)
# Car-37 started Cleaning at 640.4 | Q(Cleaning=10, Primer=0, Painting=16)
# Car-35 finished Primer at 653.1 | Q(Cleaning=10, Primer=0, Painting=16)
# Car-35 arrived at Painting at time 653.1 | Q(Cleaning=10, Primer=0, Painting=16)
# ALERT: Queue at Painting has 17 cars waiting at time 653.1
# Car-37 finished Cleaning at 657.5 | Q(Cleaning=10, Primer=0, Painting=17)
# Car-37 arrived at Primer at time 657.5 | Q(Cleaning=10, Primer=0, Painting=17)
# Car-37 started Primer at 657.5 | Q(Cleaning=9, Primer=0, Painting=17)
# Car-38 started Cleaning at 657.5 | Q(Cleaning=9, Primer=0, Painting=17)
# Car-36 finished Primer at 666.4 | Q(Cleaning=9, Primer=0, Painting=17)
# Car-36 arrived at Painting at time 666.4 | Q(Cleaning=9, Primer=0, Painting=17)
# ALERT: Queue at Painting has 18 cars waiting at time 666.4
# Car-18 finished Painting at 670.5 | Q(Cleaning=9, Primer=0, Painting=18)
# Car-18 exited system at 670.5 | Q(Cleaning=9, Primer=0, Painting=18)
# Car-19 started Painting at 670.5 | Q(Cleaning=9, Primer=0, Painting=17)
# Car-38 finished Cleaning at 673.3 | Q(Cleaning=9, Primer=0, Painting=17)
# Car-38 arrived at Primer at time 673.3 | Q(Cleaning=9, Primer=0, Painting=17)
# Car-38 started Primer at 673.3 | Q(Cleaning=8, Primer=0, Painting=17)
# Car-39 started Cleaning at 673.3 | Q(Cleaning=8, Primer=0, Painting=17)
# Car-37 finished Primer at 683.8 | Q(Cleaning=8, Primer=0, Painting=17)
# Car-37 arrived at Painting at time 683.8 | Q(Cleaning=8, Primer=0, Painting=17)
# ALERT: Queue at Painting has 18 cars waiting at time 683.8
# Car-39 finished Cleaning at 690.1 | Q(Cleaning=8, Primer=0, Painting=18)
# Car-39 arrived at Primer at time 690.1 | Q(Cleaning=8, Primer=0, Painting=18)
# Car-39 started Primer at 690.1 | Q(Cleaning=7, Primer=0, Painting=18)
# Car-40 started Cleaning at 690.1 | Q(Cleaning=7, Primer=0, Painting=18)
# Car-19 finished Painting at 705.6 | Q(Cleaning=7, Primer=0, Painting=18)
# Car-19 exited system at 705.6 | Q(Cleaning=7, Primer=0, Painting=18)
# Car-20 started Painting at 705.6 | Q(Cleaning=7, Primer=0, Painting=17)
# Car-38 finished Primer at 706.6 | Q(Cleaning=7, Primer=0, Painting=17)
# Car-38 arrived at Painting at time 706.6 | Q(Cleaning=7, Primer=0, Painting=17)
# ALERT: Queue at Painting has 18 cars waiting at time 706.6
# Car-40 finished Cleaning at 708.1 | Q(Cleaning=7, Primer=0, Painting=18)
# Car-40 arrived at Primer at time 708.1 | Q(Cleaning=7, Primer=0, Painting=18)
# Car-40 started Primer at 708.1 | Q(Cleaning=6, Primer=0, Painting=18)
# Car-41 started Cleaning at 708.1 | Q(Cleaning=6, Primer=0, Painting=18)
# Car-39 finished Primer at 724.2 | Q(Cleaning=6, Primer=0, Painting=18)
# Car-39 arrived at Painting at time 724.2 | Q(Cleaning=6, Primer=0, Painting=18)
# ALERT: Queue at Painting has 19 cars waiting at time 724.2
# Car-41 finished Cleaning at 724.5 | Q(Cleaning=6, Primer=0, Painting=19)
# Car-41 arrived at Primer at time 724.5 | Q(Cleaning=6, Primer=0, Painting=19)
# Car-41 started Primer at 724.5 | Q(Cleaning=5, Primer=0, Painting=19)
# Car-42 started Cleaning at 724.5 | Q(Cleaning=5, Primer=0, Painting=19)
# Car-20 finished Painting at 738.6 | Q(Cleaning=5, Primer=0, Painting=19)
# Car-20 exited system at 738.6 | Q(Cleaning=5, Primer=0, Painting=19)
# Car-21 started Painting at 738.6 | Q(Cleaning=5, Primer=0, Painting=18)
# Car-40 finished Primer at 739.6 | Q(Cleaning=5, Primer=0, Painting=18)
# Car-40 arrived at Painting at time 739.6 | Q(Cleaning=5, Primer=0, Painting=18)
# ALERT: Queue at Painting has 19 cars waiting at time 739.6
# Car-42 finished Cleaning at 739.7 | Q(Cleaning=5, Primer=0, Painting=19)
# Car-42 arrived at Primer at time 739.7 | Q(Cleaning=5, Primer=0, Painting=19)
# Car-42 started Primer at 739.7 | Q(Cleaning=4, Primer=0, Painting=19)
# Car-43 started Cleaning at 739.7 | Q(Cleaning=4, Primer=0, Painting=19)
# Car-41 finished Primer at 752.4 | Q(Cleaning=4, Primer=0, Painting=19)
# Car-41 arrived at Painting at time 752.4 | Q(Cleaning=4, Primer=0, Painting=19)
# ALERT: Queue at Painting has 20 cars waiting at time 752.4
# Car-43 finished Cleaning at 758.9 | Q(Cleaning=4, Primer=0, Painting=20)
# Car-43 arrived at Primer at time 758.9 | Q(Cleaning=4, Primer=0, Painting=20)
# Car-43 started Primer at 758.9 | Q(Cleaning=3, Primer=0, Painting=20)
# Car-44 started Cleaning at 758.9 | Q(Cleaning=3, Primer=0, Painting=20)
# Car-42 finished Primer at 768.5 | Q(Cleaning=3, Primer=0, Painting=20)
# Car-42 arrived at Painting at time 768.5 | Q(Cleaning=3, Primer=0, Painting=20)
# ALERT: Queue at Painting has 21 cars waiting at time 768.5
# Car-44 finished Cleaning at 774.2 | Q(Cleaning=3, Primer=0, Painting=21)
# Car-44 arrived at Primer at time 774.2 | Q(Cleaning=3, Primer=0, Painting=21)
# Car-44 started Primer at 774.2 | Q(Cleaning=2, Primer=0, Painting=21)
# Car-45 started Cleaning at 774.2 | Q(Cleaning=2, Primer=0, Painting=21)
# Car-21 finished Painting at 775.1 | Q(Cleaning=2, Primer=0, Painting=21)
# Car-21 exited system at 775.1 | Q(Cleaning=2, Primer=0, Painting=21)
# Car-22 started Painting at 775.1 | Q(Cleaning=2, Primer=0, Painting=20)
# Car-45 finished Cleaning at 792.4 | Q(Cleaning=2, Primer=0, Painting=20)
# Car-45 arrived at Primer at time 792.4 | Q(Cleaning=2, Primer=0, Painting=20)
# Car-46 started Cleaning at 792.4 | Q(Cleaning=1, Primer=1, Painting=20)
# Car-43 finished Primer at 793.4 | Q(Cleaning=1, Primer=1, Painting=20)
# Car-43 arrived at Painting at time 793.4 | Q(Cleaning=1, Primer=1, Painting=20)
# ALERT: Queue at Painting has 21 cars waiting at time 793.4
# Car-45 started Primer at 793.4 | Q(Cleaning=1, Primer=0, Painting=21)
# Car-44 finished Primer at 807.6 | Q(Cleaning=1, Primer=0, Painting=21)
# Car-44 arrived at Painting at time 807.6 | Q(Cleaning=1, Primer=0, Painting=21)
# ALERT: Queue at Painting has 22 cars waiting at time 807.6
# Car-22 finished Painting at 808.1 | Q(Cleaning=1, Primer=0, Painting=22)
# Car-22 exited system at 808.1 | Q(Cleaning=1, Primer=0, Painting=22)
# Car-23 started Painting at 808.1 | Q(Cleaning=1, Primer=0, Painting=21)
# Car-46 finished Cleaning at 811.0 | Q(Cleaning=1, Primer=0, Painting=21)
# Car-46 arrived at Primer at time 811.0 | Q(Cleaning=1, Primer=0, Painting=21)
# Car-46 started Primer at 811.0 | Q(Cleaning=0, Primer=0, Painting=21)
# Car-47 started Cleaning at 811.0 | Q(Cleaning=0, Primer=0, Painting=21)
# Car-45 finished Primer at 826.3 | Q(Cleaning=0, Primer=0, Painting=21)
# Car-45 arrived at Painting at time 826.3 | Q(Cleaning=0, Primer=0, Painting=21)
# ALERT: Queue at Painting has 22 cars waiting at time 826.3
# Car-47 finished Cleaning at 829.2 | Q(Cleaning=0, Primer=0, Painting=22)
# Car-47 arrived at Primer at time 829.2 | Q(Cleaning=0, Primer=0, Painting=22)
# Car-47 started Primer at 829.2 | Q(Cleaning=0, Primer=0, Painting=22)
# Car-46 finished Primer at 837.1 | Q(Cleaning=0, Primer=0, Painting=22)
# Car-46 arrived at Painting at time 837.1 | Q(Cleaning=0, Primer=0, Painting=22)
# ALERT: Queue at Painting has 23 cars waiting at time 837.1
# Car-23 finished Painting at 840.6 | Q(Cleaning=0, Primer=0, Painting=23)
# Car-23 exited system at 840.6 | Q(Cleaning=0, Primer=0, Painting=23)
# Car-24 started Painting at 840.6 | Q(Cleaning=0, Primer=0, Painting=22)
# Car-47 finished Primer at 857.2 | Q(Cleaning=0, Primer=0, Painting=22)
# Car-47 arrived at Painting at time 857.2 | Q(Cleaning=0, Primer=0, Painting=22)
# ALERT: Queue at Painting has 23 cars waiting at time 857.2
# Car-24 finished Painting at 876.5 | Q(Cleaning=0, Primer=0, Painting=23)
# Car-24 exited system at 876.5 | Q(Cleaning=0, Primer=0, Painting=23)
# Car-25 started Painting at 876.5 | Q(Cleaning=0, Primer=0, Painting=22)
# Car-25 finished Painting at 911.9 | Q(Cleaning=0, Primer=0, Painting=22)
# Car-25 exited system at 911.9 | Q(Cleaning=0, Primer=0, Painting=22)
# Car-26 started Painting at 911.9 | Q(Cleaning=0, Primer=0, Painting=21)
# Car-26 finished Painting at 950.5 | Q(Cleaning=0, Primer=0, Painting=21)
# Car-26 exited system at 950.5 | Q(Cleaning=0, Primer=0, Painting=21)
# Car-27 started Painting at 950.5 | Q(Cleaning=0, Primer=0, Painting=20)
# Car-27 finished Painting at 988.5 | Q(Cleaning=0, Primer=0, Painting=20)
# Car-27 exited system at 988.5 | Q(Cleaning=0, Primer=0, Painting=20)
# Car-28 started Painting at 988.5 | Q(Cleaning=0, Primer=0, Painting=19)
# Car-28 finished Painting at 1024.4 | Q(Cleaning=0, Primer=0, Painting=19)
# Car-28 exited system at 1024.4 | Q(Cleaning=0, Primer=0, Painting=19)
# Car-29 started Painting at 1024.4 | Q(Cleaning=0, Primer=0, Painting=18)
# Car-29 finished Painting at 1064.2 | Q(Cleaning=0, Primer=0, Painting=18)
# Car-29 exited system at 1064.2 | Q(Cleaning=0, Primer=0, Painting=18)
# Car-30 started Painting at 1064.2 | Q(Cleaning=0, Primer=0, Painting=17)
# Car-30 finished Painting at 1099.0 | Q(Cleaning=0, Primer=0, Painting=17)
# Car-30 exited system at 1099.0 | Q(Cleaning=0, Primer=0, Painting=17)
# Car-31 started Painting at 1099.0 | Q(Cleaning=0, Primer=0, Painting=16)
# Car-31 finished Painting at 1134.6 | Q(Cleaning=0, Primer=0, Painting=16)
# Car-31 exited system at 1134.6 | Q(Cleaning=0, Primer=0, Painting=16)
# Car-32 started Painting at 1134.6 | Q(Cleaning=0, Primer=0, Painting=15)
# Car-32 finished Painting at 1167.5 | Q(Cleaning=0, Primer=0, Painting=15)
# Car-32 exited system at 1167.5 | Q(Cleaning=0, Primer=0, Painting=15)
# Car-33 started Painting at 1167.5 | Q(Cleaning=0, Primer=0, Painting=14)
# Car-33 finished Painting at 1201.5 | Q(Cleaning=0, Primer=0, Painting=14)
# Car-33 exited system at 1201.5 | Q(Cleaning=0, Primer=0, Painting=14)
# Car-34 started Painting at 1201.5 | Q(Cleaning=0, Primer=0, Painting=13)
# Car-34 finished Painting at 1236.6 | Q(Cleaning=0, Primer=0, Painting=13)
# Car-34 exited system at 1236.6 | Q(Cleaning=0, Primer=0, Painting=13)
# Car-35 started Painting at 1236.6 | Q(Cleaning=0, Primer=0, Painting=12)
# Car-35 finished Painting at 1271.7 | Q(Cleaning=0, Primer=0, Painting=12)
# Car-35 exited system at 1271.7 | Q(Cleaning=0, Primer=0, Painting=12)
# Car-36 started Painting at 1271.7 | Q(Cleaning=0, Primer=0, Painting=11)
# Car-36 finished Painting at 1302.9 | Q(Cleaning=0, Primer=0, Painting=11)
# Car-36 exited system at 1302.9 | Q(Cleaning=0, Primer=0, Painting=11)
# Car-37 started Painting at 1302.9 | Q(Cleaning=0, Primer=0, Painting=10)
# Car-37 finished Painting at 1337.8 | Q(Cleaning=0, Primer=0, Painting=10)
# Car-37 exited system at 1337.8 | Q(Cleaning=0, Primer=0, Painting=10)
# Car-38 started Painting at 1337.8 | Q(Cleaning=0, Primer=0, Painting=9)
# Car-38 finished Painting at 1377.6 | Q(Cleaning=0, Primer=0, Painting=9)
# Car-38 exited system at 1377.6 | Q(Cleaning=0, Primer=0, Painting=9)
# Car-39 started Painting at 1377.6 | Q(Cleaning=0, Primer=0, Painting=8)
# Car-39 finished Painting at 1412.5 | Q(Cleaning=0, Primer=0, Painting=8)
# Car-39 exited system at 1412.5 | Q(Cleaning=0, Primer=0, Painting=8)
# Car-40 started Painting at 1412.5 | Q(Cleaning=0, Primer=0, Painting=7)
# Car-40 finished Painting at 1450.9 | Q(Cleaning=0, Primer=0, Painting=7)
# Car-40 exited system at 1450.9 | Q(Cleaning=0, Primer=0, Painting=7)
# Car-41 started Painting at 1450.9 | Q(Cleaning=0, Primer=0, Painting=6)
# Car-41 finished Painting at 1490.7 | Q(Cleaning=0, Primer=0, Painting=6)
# Car-41 exited system at 1490.7 | Q(Cleaning=0, Primer=0, Painting=6)
# Car-42 started Painting at 1490.7 | Q(Cleaning=0, Primer=0, Painting=5)
# Car-42 finished Painting at 1523.0 | Q(Cleaning=0, Primer=0, Painting=5)
# Car-42 exited system at 1523.0 | Q(Cleaning=0, Primer=0, Painting=5)
# Car-43 started Painting at 1523.0 | Q(Cleaning=0, Primer=0, Painting=4)
# Car-43 finished Painting at 1557.2 | Q(Cleaning=0, Primer=0, Painting=4)
# Car-43 exited system at 1557.2 | Q(Cleaning=0, Primer=0, Painting=4)
# Car-44 started Painting at 1557.2 | Q(Cleaning=0, Primer=0, Painting=3)
# Car-44 finished Painting at 1588.3 | Q(Cleaning=0, Primer=0, Painting=3)
# Car-44 exited system at 1588.3 | Q(Cleaning=0, Primer=0, Painting=3)
# Car-45 started Painting at 1588.3 | Q(Cleaning=0, Primer=0, Painting=2)
# Car-45 finished Painting at 1628.2 | Q(Cleaning=0, Primer=0, Painting=2)
# Car-45 exited system at 1628.2 | Q(Cleaning=0, Primer=0, Painting=2)
# Car-46 started Painting at 1628.2 | Q(Cleaning=0, Primer=0, Painting=1)
# Car-46 finished Painting at 1665.0 | Q(Cleaning=0, Primer=0, Painting=1)
# Car-46 exited system at 1665.0 | Q(Cleaning=0, Primer=0, Painting=1)
# Car-47 started Painting at 1665.0 | Q(Cleaning=0, Primer=0, Painting=0)
# Car-47 finished Painting at 1698.4 | Q(Cleaning=0, Primer=0, Painting=0)
# Car-47 exited system at 1698.4 | Q(Cleaning=0, Primer=0, Painting=0)

# %%
print("\n===== Paint Shop Simulation Results =====")

# env.now gives the actual time when the last car exits the system
print(f"Simulation ended at: {env.now:.2f} minutes")
print(f"Total cars completed: {completed_cars}")

# Average total time spent by a car in the system
print(f"Average system time per car: {statistics.mean(system_times):.2f} minutes\n")

# Station capacities (needed for utilization calculation)
capacity = {
    "Cleaning": CLEAN_MACHINES,
    "Primer": PRIMER_MACHINES,
    "Painting": PAINT_MACHINES
}

for station in ["Cleaning", "Primer", "Painting"]:

    # Utilization = busy time during shift / total available machine time
    utilization = (busy_time[station] / (SHIFT_TIME * capacity[station])) * 100

    avg_wait = statistics.mean(wait_times[station]) if wait_times[station] else 0

    print(f"{station} Station:")
    print(f"- Utilization: {utilization:.2f}%")
    print(f"- Max queue length: {queue_max[station]}")
    print(f"- Avg waiting time: {avg_wait:.2f} minutes\n")

print(f"Alerts triggered: {alerts_triggered}")
# Out:
# ===== Paint Shop Simulation Results =====
# Simulation ended at: 1698.42 minutes
# Total cars completed: 47
# Average system time per car: 645.15 minutes
#
# Cleaning Station:
# - Utilization: 98.21%
# - Max queue length: 19
# - Avg waiting time: 163.48 minutes
#
# Primer Station:
# - Utilization: 84.18%
# - Max queue length: 1
# - Avg waiting time: 0.25 minutes
#
# Painting Station:
# - Utilization: 89.16%
# - Max queue length: 23
# - Avg waiting time: 398.22 minutes
#
# Alerts triggered: 79
